# %%
import numpy as np 
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score, classification_report
pd.set_option('display.max_columns',None)

# %%
data1=pd.read_csv('T1.csv')
data2=pd.read_csv('T2.csv')
data3=pd.concat([data1, data2], axis=0, ignore_index=True)
data3 = data3.sample(frac=1, random_state=42).reset_index(drop=True)

data3.shape
# Out:
# (246945, 378)

# %%
X = data3.iloc[:, 1:]  # Features, assuming the first column is 'disease_name'
y = data3.iloc[:, 0]   # Labels, assuming the first column is 'disease_name'
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.3, random_state=42)

# Initialize the Random Forest Classifier and MultiOutputClassifier
rf = RandomForestClassifier(n_estimators=120, random_state=42)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=120, random_state=42)

# %%
y_pred = rf.predict(X_test)

# Evaluate the model's performance using accuracy
print("Accuracy for disease prediction: {:.4f}".format(accuracy_score(y_test, y_pred)))

# Print detailed classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, zero_division=1))
# Out:
# Accuracy for disease prediction: 0.8383
#
# Classification Report:
#                                                           precision    recall  f1-score   support
#
#                                abdominal aortic aneurysm       1.00      0.97      0.99        40
#                                         abdominal hernia       0.95      0.95      0.95       118
#                                          abscess of nose       0.91      0.83      0.87        99
#                                      abscess of the lung       1.00      1.00      1.00         6
#                                   abscess of the pharynx       0.87      0.89      0.88        90
#                                     acanthosis nigricans       0.71      1.00      0.83        10
#                                                acariasis       1.00      0.88      0.93         8
#                                                achalasia       0.71      0.83      0.76        29
# ...
